# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv("../data/quikr_car.csv")

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.sample(10)
# Out:
#                                         name     company  year      Price  \
# 417                       Mahindra XUV500 W8    Mahindra  2012   5,60,000
# 578                 Chevrolet Beat LS Diesel   Chevrolet  2016   2,25,000
# 74                          Datsun Redi GO S      Datsun  2017   2,35,000
# 679                          Mahindra KUV100    Mahindra  2017   3,60,000
# 59            Maruti Suzuki Wagon R LX BS IV      Maruti  2013     85,000
# 283            Tata Indigo eCS LX TDI BS III        Tata  2016   3,20,000
# 60                                 Ford Figo        Ford  2012   1,75,000
# 73                         Mini Cooper S 1.6        Mini  2013  18,91,111
# 398  Volkswagen Vento Konekt Diesel Highline  Volkswagen  2011   2,45,000
# 692                      Volvo S80 Summum D4       Volvo  2015  18,50,000
#
#        kms_driven fuel_type
# 417  1,00,000 kms    Diesel
# 578    95,000 kms    Diesel
# 74     16,000 kms    Petrol
# 679    35,000 kms    Diesel
# ...

# %%
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car['kms_driven'].sample(10)
# Out:
# 475    55,000 kms
# 860    42,000 kms
# 116    51,000 kms
# 352    22,000 kms
# 50     23,452 kms
# 328    35,000 kms
# 550    10,000 kms
# 168    50,000 kms
# 31     48,508 kms
# 423    68,000 kms
# Name: kms_driven, dtype: object

# %% [markdown]
# ## Qyality
# - year has many non year values
# - year object to int
# - price has ask for price
# - price object to integer
# - kms-driven are in object, kms written at the end, comma in between
# - kms-driven has nan values
# - keep first 3 words of the name

# %% [markdown]
# # Cleaning data

# %%
copy_data=car.copy()

# %%
car=car[car['year'].str.isnumeric()]

# %%
car['year']=car['year'].astype(int)

# %%
car['year']
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 886    2009
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 842, dtype: int32

# %%
car=car[car['Price']!="Ask For Price"]

# %%
car['Price']=car['Price'].str.replace(',', '').astype(int)

# %%
car
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int32
#  3   Price       819 non-null    int32
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 38.4+ KB

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0)

# %%
car
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0       45,000    Petrol
# 1           40    Diesel
# 3       28,000    Petrol
# 4       36,000    Diesel
# ...

# %%
car=car[car['kms_driven']!='Petrol']

# %%
car['kms_driven']=car['kms_driven'].str.replace(',', '').astype(int)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14004\3168495393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['kms_driven']=car['kms_driven'].str.replace(',', '').astype(int)

# %%
car['kms_driven']
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# 888     27000
# 889     40000
# Name: kms_driven, Length: 817, dtype: int32

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int32
#  3   Price       817 non-null    int32
#  4   kms_driven  817 non-null    int32
#  5   fuel_type   816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
car.dropna(inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14004\607812524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car.dropna(inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int32
#  3   Price       816 non-null    int32
#  4   kms_driven  816 non-null    int32
#  5   fuel_type   816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
car['name']=car['name'].str.split(' ').str[:3].str.join(' ')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14004\3543884952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['name']=car['name'].str.split(' ').str[:3].str.join(' ')

# %%
car.reset_index(drop=True)
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
car.describe()
# Out:
#               year         Price     kms_driven
# count   816.000000  8.160000e+02     816.000000
# mean   2012.444853  4.117176e+05   46275.531863
# std       4.002992  4.751844e+05   34297.428044
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.912500e+05   56818.500000
# max    2019.000000  8.500003e+06  400000.000000

# %% [markdown]
# ## outlier
# - so there is 1 car which is of 85e5 means 85 lakh so we are goun to remove that comlumn

# %%
car=car[car['Price']<4e6]

# %%
car
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [815 rows x 6 columns]

# %%
car.to_csv("../data/cleaned_car.csv")

# %% [markdown]
# ## Model

# %%
x=car.drop(columns='Price')

# %%
y=car['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#                      name   company  year  kms_driven fuel_type
# 266    Maruti Suzuki Ritz    Maruti  2013       33000    Diesel
# 794         Hyundai Eon D   Hyundai  2013       20000    Petrol
# 749        Honda City 1.5     Honda  2005       68000    Petrol
# 793      Mahindra Xylo E8  Mahindra  2011       43000    Diesel
# 262  Maruti Suzuki Ertiga    Maruti  2014       45000    Petrol
# ..                    ...       ...   ...         ...       ...
# 41         Honda City 1.5     Honda  2011       33000    Petrol
# 121   Maruti Suzuki Dzire    Maruti  2015      104000    Diesel
# 125    Maruti Suzuki Alto    Maruti  2017        5600    Petrol
# 464     Hyundai Elite i20   Hyundai  2015       20000    Petrol
# 682   Maruti Suzuki Swift    Maruti  2017       41800    Diesel
#
# [652 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans= make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                      remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# c:\Users\hp\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5525077915585119

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

lr = LinearRegression()
pipe = make_pipeline(column_trans, lr)

scores = cross_val_score(pipe, x, y, cv=20, scoring="r2")
print("Mean R²:", np.mean(scores))
# Out:
# Mean R²: 0.5180030756913716

# %%
from sklearn.model_selection import ShuffleSplit

cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=42)
scores = cross_val_score(pipe, x, y, cv=cv, scoring="r2")

# %%
scores = cross_val_score(pipe, x, y, cv=cv, scoring="r2", n_jobs=-1)

# %%
np.argmax(scores)
# Out:
# 3

# %%
scores[np.argmax(scores)]
# Out:
# 0.8239666470711123

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5370851059720391

# %%
import pickle

# %%
pickle.dump(pipe,open('../models/LinerRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Mahindra Jeep CL550','Mahindra',2006,100,'Diesel']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([233346.96913294])

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\hp\\OneDrive\\Desktop\\car_price_predection\\notebook'

# %%
car = pd.read_csv("../data/cleaned_car.csv")
car_names = sorted(car['name'].unique())

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.2
